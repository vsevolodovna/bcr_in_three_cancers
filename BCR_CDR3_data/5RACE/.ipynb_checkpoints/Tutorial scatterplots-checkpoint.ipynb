# %%
import numpy as np
import pandas as pd
import os
from os import path
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline 
import seaborn as sns
import re

import itertools
from itertools import combinations
from itertools import (takewhile,repeat)

# %%
path_to_files='/home/sofyakrasik/VDJconverted/' 
pattern='lcp3' #pattern in filename

top_max=1000 #we are not interested in top higher than 1000

files=[f for f in os.listdir(path_to_files) if re.match('.*'+pattern+'.*'+'IGH.txt',f)]

data=pd.DataFrame()

for f in files:
    df=pd.read_csv(path_to_files+f,sep='\t')
    df=df[['freq','cdr3nt']]
    df['filename']=f
    df=df.head(top_max)
    data=data.append(df)

data['freq']=data.groupby(['cdr3nt','filename'])['freq'].transform('sum')
data=data.drop_duplicates(['cdr3nt','filename']).copy()

#TO HAVE THE SAME SCALE FOR ALL PLOTS
fmin=data['freq'].min()
fmax=data['freq'].max()

# %%
#CREATE ALL POSSIBLE PAIRS OF SAMPLES
pairs=list(itertools.combinations(files, 2))

for p in pairs:
    l=list(p)
    l.sort()
    smp1=l[0]
    smp2=l[1]
    
    df1=data[data['filename']==smp1].copy()
    df2=data[data['filename']==smp2].copy()
    
    topn=min(len(df1),len(df2))
    
    df1=df1.sort_values('freq',ascending=False)
    df2=df2.sort_values('freq',ascending=False)
    
    df1=df1.head(topn)
    df2=df2.head(topn)
    
    #IF YOU NEED FREQUENCY RECALCULATION
    #df1['freq']=df1['freq']/df1['freq'].sum()
    #df2['freq']=df2['freq']/df2['freq'].sum()
    
    
    plt.figure(figsize=(5,5))
    
    plot_data=pd.merge(df1,df2,how='outer',on='cdr3nt')
    plot_data=plot_data[['cdr3nt','freq_x','freq_y']]
    #OTHERWISE WE CANNOT HAVE LOG SCALE
    plot_data= plot_data.apply(lambda x: x.fillna(fmin*0.7))
    
    plt.xlim(fmin/2,fmax)
    plt.ylim(fmin/2,fmax)
    plt.xscale('log')
    plt.yscale('log')
    
    sns.scatterplot(x='freq_x',y='freq_y',data=plot_data,s=100,linewidth=0,alpha=0.3)
    
    
    plt.xlabel(smp1.split('.')[0], fontsize=10)
    plt.ylabel(smp2.split('.')[0], fontsize=10)
    plt.title('top='+str(topn), fontsize=20)
    
    plt.show()
